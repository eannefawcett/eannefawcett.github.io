# %% [markdown]
# # <center>Maximum Likelihood Estimation

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [2, 6, 3, 4, 4, 5, 5, 5, 8, 9]
z = [0,0,0,0,0.05,0,0,0.05,0,0]

# %%
plt.scatter(data,z,c='r',s=200)
plt.ylim(0,0.1)
# Out:
# (0, 0.1)

# %%
mu = 4
sigma = 1
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.scatter(data,z,c='r',s=200);

# %%
sum(stats.norm(mu,sigma).pdf(z))
# Out:
# 0.001397154623651567

# %%
mu = np.mean(data)
sigma = np.std(data)
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.scatter(data,z,c='r',s=200);

# %%
sum(stats.norm(mu,sigma).pdf(z))
# Out:
# 0.08310815417392406

# %% [markdown]
# # <center> MLE vs MAP

# %% [markdown]
# ## <center> MAP - Maximum A Posteriori Estimation (Bayes) whereas MLE is Frequentist

# %% [markdown]
# Consider flipping a coin 10 times...

# %%
flips = ['H', 'T', 'H', 'H', 'H', 'H', 'T', 'T', 'H','T']

# %% [markdown]
# What are the odds of heads?

# %% [markdown]
# MLE approach...

# %%
flips.count('H'), flips.count('T')
# Out:
# (6, 4)

# %%
odds_of_heads = flips.count('H')/len(flips)
print('The odds of heads is:', odds_of_heads)
# Out:
# The odds of heads is: 0.6

# %% [markdown]
# MAP approach...

# %%
prior_prob = 0.5
odds_of_heads = flips.count('H')/len(flips)

# %%
(prior_prob+odds_of_heads)/2
# Out:
# 0.55

# %% [markdown]
# ### MAP combines prior knowledge and the observed knowledge

# %% [markdown]
# Say we roll a die 10 times and get the following results

# %%
rolls = [1,5,2,2,5,6,4,6,1,5]

# %%
## MLE
probs = [rolls.count(x)/len(rolls) for x in range(1,7)]
probs
#best for uniform distributions
# Out:
# [0.2, 0.2, 0.0, 0.1, 0.3, 0.2]

# %%
## MAP
prior_probs = [1/6]*6
map_probs = [(x+y)/2 for x,y in zip(probs,prior_probs)]
map_probs
#better for a smaller sample size due to incorporation of prior knowledge
# Out:
# [0.18333333333333335,
#  0.18333333333333335,
#  0.08333333333333333,
#  0.13333333333333333,
#  0.23333333333333334,
#  0.18333333333333335]

# %% [markdown]
# ## <center> Resources

# %% [markdown]
# <b>StatQuest</b> <br><br>
# https://www.youtube.com/watch?v=XepXtl9YKwc <br><br>
# https://www.youtube.com/watch?v=Dn6b9fCIUpM <br><br> Proof for MLE
#
# <b>A gentle introduction</b><br><br>
# https://towardsdatascience.com/a-gentle-introduction-to-maximum-likelihood-estimation-9fbff27ea12f
